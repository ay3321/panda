# %%
dataset = [
    ['tea','orange','nuts','tomato milk','suger','ben'],
    ['date','orange','nuts','tomato milk','suger','ben'],
    ['tea','banana','tomato milk','suger'],
    ['tea','Unico','cornflex','tomato milk','ben'],
    ['cornflex','orange','orange','tomato milk','Ice cream','suger'],
]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
dataset
# Out:
# [['tea', 'orange', 'nuts', 'tomato milk', 'suger', 'ben'],
#  ['date', 'orange', 'nuts', 'tomato milk', 'suger', 'ben'],
#  ['tea', 'banana', 'tomato milk', 'suger'],
#  ['tea', 'Unico', 'cornflex', 'tomato milk', 'ben'],
#  ['cornflex', 'orange', 'orange', 'tomato milk', 'Ice cream', 'suger']]

# %%
te= TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)

# %%
df = pd.DataFrame(te_ary,columns=te.columns_)
df
# Out:
#    Ice cream  Unico  banana    ben  cornflex   date   nuts  orange  suger  \
# 0      False  False   False   True     False  False   True    True   True
# 1      False  False   False   True     False   True   True    True   True
# 2      False  False    True  False     False  False  False   False   True
# 3      False   True   False   True      True  False  False   False  False
# 4       True  False   False  False      True  False  False    True   True
#
#      tea  tomato milk
# 0   True         True
# 1  False         True
# 2   True         True
# 3   True         True
# 4  False         True

# %%
from mlxtend.frequent_patterns import apriori
frequent_itemsets =apriori(df,min_support=0.6,use_colnames=True)
frequent_itemsets
# Out:
#     support                      itemsets
# 0       0.6                         (ben)
# 1       0.6                      (orange)
# 2       0.8                       (suger)
# 3       0.6                         (tea)
# 4       1.0                 (tomato milk)
# 5       0.6            (tomato milk, ben)
# 6       0.6               (orange, suger)
# 7       0.6         (orange, tomato milk)
# 8       0.8          (tomato milk, suger)
# 9       0.6            (tomato milk, tea)
# 10      0.6  (orange, tomato milk, suger)

# %%
from mlxtend.frequent_patterns import association_rules
res = association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7)
res
# Out:
#               antecedents            consequents  antecedent support  \
# 0                   (ben)          (tomato milk)                 0.6
# 1                (orange)                (suger)                 0.6
# 2                 (suger)               (orange)                 0.8
# 3                (orange)          (tomato milk)                 0.6
# 4           (tomato milk)                (suger)                 1.0
# 5                 (suger)          (tomato milk)                 0.8
# 6                   (tea)          (tomato milk)                 0.6
# 7   (orange, tomato milk)                (suger)                 0.6
# 8         (orange, suger)          (tomato milk)                 0.6
# 9    (tomato milk, suger)               (orange)                 0.8
# 10               (orange)   (tomato milk, suger)                 0.6
# 11                (suger)  (orange, tomato milk)                 0.8
#
# ...

# %%
res_1 = res[['antecedents','consequents','support','confidence','lift']]
res_1
# Out:
#               antecedents            consequents  support  confidence  lift
# 0                   (ben)          (tomato milk)      0.6        1.00  1.00
# 1                (orange)                (suger)      0.6        1.00  1.25
# 2                 (suger)               (orange)      0.6        0.75  1.25
# 3                (orange)          (tomato milk)      0.6        1.00  1.00
# 4           (tomato milk)                (suger)      0.8        0.80  1.00
# 5                 (suger)          (tomato milk)      0.8        1.00  1.00
# 6                   (tea)          (tomato milk)      0.6        1.00  1.00
# 7   (orange, tomato milk)                (suger)      0.6        1.00  1.25
# 8         (orange, suger)          (tomato milk)      0.6        1.00  1.00
# 9    (tomato milk, suger)               (orange)      0.6        0.75  1.25
# 10               (orange)   (tomato milk, suger)      0.6        1.00  1.25
# ...

# %%
res_2 = res_1[res_1['confidence'] >=1]
res_2
# Out:
#               antecedents           consequents  support  confidence  lift
# 0                   (ben)         (tomato milk)      0.6         1.0  1.00
# 1                (orange)               (suger)      0.6         1.0  1.25
# 3                (orange)         (tomato milk)      0.6         1.0  1.00
# 5                 (suger)         (tomato milk)      0.8         1.0  1.00
# 6                   (tea)         (tomato milk)      0.6         1.0  1.00
# 7   (orange, tomato milk)               (suger)      0.6         1.0  1.25
# 8         (orange, suger)         (tomato milk)      0.6         1.0  1.00
# 10               (orange)  (tomato milk, suger)      0.6         1.0  1.25
