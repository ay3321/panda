# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("desktop/Sleep_health_and_lifestyle_dataset.csv")
print(df.to_string())
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0            1    Male   27     Software Engineer             6.1                 6                       40             6     Overweight         126/83          77         4200           None
# 1            2    Male   28                Doctor             6.2                 6                       60             8         Normal         125/80          75        10000           None
# 2            3    Male   28                Doctor             6.2                 6                       60             8         Normal         125/80          75        10000           None
# 3            4    Male   28  Sales Representative             5.9                 4                       30             8          Obese         140/90          85         3000    Sleep Apnea
# ...

# %%
new_df=df.dropna()
print(new_df.to_string())
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0            1    Male   27     Software Engineer             6.1                 6                       40             6     Overweight         126/83          77         4200           None
# 1            2    Male   28                Doctor             6.2                 6                       60             8         Normal         125/80          75        10000           None
# 2            3    Male   28                Doctor             6.2                 6                       60             8         Normal         125/80          75        10000           None
# 3            4    Male   28  Sales Representative             5.9                 4                       30             8          Obese         140/90          85         3000    Sleep Apnea
# ...

# %%
for x in new_df.index:
  if 'Male'!= new_df.loc[x, 'Gender'] != 'Female':
    new_df.drop(x, inplace=True)
print(df.to_string())
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0            1    Male   27     Software Engineer             6.1                 6                       40             6     Overweight         126/83          77         4200           None
# 1            2    Male   28                Doctor             6.2                 6                       60             8         Normal         125/80          75        10000           None
# 2            3    Male   28                Doctor             6.2                 6                       60             8         Normal         125/80          75        10000           None
# 3            4    Male   28  Sales Representative             5.9                 4                       30             8          Obese         140/90          85         3000    Sleep Apnea
# ...

# %%
for x in new_df.index:
  if ~(30 <= new_df.loc[x, 'Age'] <= 40):
    new_df.drop(x, inplace=True)
print(new_df.to_string())
# Out:
#      Person ID  Gender  Age         Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 19          20    Male   30             Doctor             7.6                 7                       75             6         Normal         120/80          70         8000           None
# 20          21    Male   30             Doctor             7.7                 7                       75             6         Normal         120/80          70         8000           None
# 21          22    Male   30             Doctor             7.7                 7                       75             6         Normal         120/80          70         8000           None
# 22          23    Male   30             Doctor             7.7                 7                       75             6         Normal         120/80          70         8000           None
# ...

# %%
for i in new_df.index:
  if ~(6 <= new_df.loc[i,'Stress Level']<= 8):
        new_df.drop(i, inplace=True)
print(new_df.to_string())
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 19          20    Male   30      Doctor             7.6                 7                       75             6         Normal         120/80          70         8000           None
# 20          21    Male   30      Doctor             7.7                 7                       75             6         Normal         120/80          70         8000           None
# 21          22    Male   30      Doctor             7.7                 7                       75             6         Normal         120/80          70         8000           None
# 22          23    Male   30      Doctor             7.7                 7                       75             6         Normal         120/80          70         8000           None
# ...

# %%
for x in new_df.index:
  if ~(40 <= new_df.loc[x,'Physical Activity Level']<=60):
        new_df.drop(x, inplace=True)
print(new_df.to_string())
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 66          67    Male   32  Accountant             7.2                 8                       50             6  Normal Weight         118/76          68         7000           None
# 68          69  Female   33   Scientist             6.2                 6                       50             6     Overweight         128/85          76         5500           None
# 69          70  Female   33   Scientist             6.2                 6                       50             6     Overweight         128/85          76         5500           None
# 106        107  Female   37       Nurse             6.1                 6                       42             6     Overweight         126/83          77         4200           None
# ...

# %%
for x in new_df.index:
  if ~(70 <= new_df.loc[x,'Heart Rate']<=78):
        new_df.drop(x, inplace=True)
print(new_df.to_string())
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 68          69  Female   33   Scientist             6.2                 6                       50             6     Overweight         128/85          76         5500           None
# 69          70  Female   33   Scientist             6.2                 6                       50             6     Overweight         128/85          76         5500           None
# 106        107  Female   37       Nurse             6.1                 6                       42             6     Overweight         126/83          77         4200           None
# 148        149  Female   39      Lawyer             6.9                 7                       50             6  Normal Weight         128/85          75         5500           None
# ...

# %%
for x in new_df.index:
  if ~(5000 <= new_df.loc[x,'Daily Steps']<=7000):
        new_df.drop(x, inplace=True)
print(new_df.to_string())
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  Physical Activity Level  Stress Level   BMI Category Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 68          69  Female   33  Scientist             6.2                 6                       50             6     Overweight         128/85          76         5500           None
# 69          70  Female   33  Scientist             6.2                 6                       50             6     Overweight         128/85          76         5500           None
# 148        149  Female   39     Lawyer             6.9                 7                       50             6  Normal Weight         128/85          75         5500           None

# %%
df['Sleep Disorder'] = df['Sleep Disorder'].str.replace('None', 'Sleep Apnea')
print(df)
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       40             6   Overweight
# ...
